# %%
import sys
import os
sys.path.append('..')

# %%
from src.kalman import KalmanFilter1D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('datasets/supplemental_data.csv', delimiter='\t', header=1)

# %%
data.shape
# Out:
# (2308, 90)

# %%
data.head()
# Out:
#    Image Id.                                   Gene Description  EWS-T1  \
# 0    21652.0  catenin (cadherin-associated protein), alpha 1...  3.2025
# 1    25725.0         farnesyl-diphosphate farnesyltransferase 1  0.0681
# 2    26184.0                      phosphofructokinase, platelet  1.0460
# 3    22260.0                                     cytochrome c-1  0.1243
# 4    22293.0  uroporphyrinogen III synthase (congenital eryt...  0.4941
#
#    EWS-T2  EWS-T3  EWS-T4  EWS-T6  EWS-T7  EWS-T9  EWS-T11  ...  TEST-20  \
# 0  1.6547  3.2779  1.0060  2.7098  2.0588  1.8483   2.7140  ...   3.0381
# 1  0.0710  0.1160  0.1906  0.2367  0.0823  0.1234   0.1805  ...   0.1378
# 2  1.0409  0.8926  0.4302  0.3693  0.9021  0.9983   0.4964  ...   1.2505
# 3  0.0520  0.1014  0.1035  0.2190  0.1288  0.2203   0.2509  ...   0.2309
# 4  0.2045  0.2818  0.2984  0.3711  0.3961  0.3766   0.4754  ...   0.3002
#
#    TEST-17  TEST-18  TEST-22  TEST-16  TEST-23  TEST-14  TEST-25  TEST-15  \
# ...

# %%
_filter = KalmanFilter1D(data.loc[0, data.columns[2:]].values.astype(np.float32), q=1, r=100)
_filter.fit()

# %%
ax = _filter.plot(fig_size=(20, 5))
# ax.plot(y, label='real data', color='magenta')
plt.legend()
plt.grid()
plt.savefig(f'figures\\notebook1_test.png', format='png', dpi=150, quality=100)
plt.show()
